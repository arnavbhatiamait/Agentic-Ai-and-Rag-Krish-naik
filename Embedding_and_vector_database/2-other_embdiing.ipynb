# %%
import os 
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_ollama import OllamaEmbeddings

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## Openai

# %%
embedding_openai=OpenAIEmbeddings(model="text-embedding-3-small",openai_api_key=openai_api_key)
embed_data=embedding_openai.embed_query("What is Langchain?")
print(embed_data)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 embedding_openai=OpenAIEmbeddings(model="text-embedding-3-small",openai_api_key=openai_api_key)
# ----> 2 embed_data=embedding_openai.embed_query("What is Langchain?")
#       3 print(embed_data)
#
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\langchain_openai\embeddings\base.py:629, in OpenAIEmbeddings.embed_query(self, text)
#     620 def embed_query(self, text: str) -> List[float]:
#     621     """Call out to OpenAI's embedding endpoint for embedding query text.
#     622
#     623     Args:
#    (...)
#     627         Embedding for the text.
#     628     """
# --> 629     return self.embed_documents([text])[0]
#
# ...

# %%
single_text="Langchain and Rag are amazing frameworks for building LLM applications. They provide tools and abstractions to make it easier to work with language models and create powerful applications."
single_text_embedding_openai=embedding_openai.embed_query(single_text)
print(single_text_embedding_openai)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 single_text="Langchain and Rag are amazing frameworks for building LLM applications. They provide tools and abstractions to make it easier to work with language models and create powerful applications."
# ----> 2 single_text_embedding_openai=embedding_openai.embed_query(single_text)
#       3 print(single_text_embedding_openai)
#
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\langchain_openai\embeddings\base.py:629, in OpenAIEmbeddings.embed_query(self, text)
#     620 def embed_query(self, text: str) -> List[float]:
#     621     """Call out to OpenAI's embedding endpoint for embedding query text.
#     622
#     623     Args:
#    (...)
#     627         Embedding for the text.
#     628     """
# --> 629     return self.embed_documents([text])[0]
#
# ...

# %%
from langchain_openai import OpenAIEmbeddings

# Different OpenAI embedding models
models_comparison = {
    "text-embedding-3-small": {
        "dimensions": 1536,
        "description": "Good balance of performance and cost",
        "cost_per_1m_tokens": 0.02,
        "use_case": "General purpose, cost-effective"
    },
    "text-embedding-3-large": {
        "dimensions": 3072,
        "description": "Highest quality embeddings",
        "cost_per_1m_tokens": 0.13,
        "use_case": "When accuracy is critical"
    },
    "text-embedding-ada-002": {
        "dimensions": 1536,
        "description": "Previous generation model",
        "cost_per_1m_tokens": 0.10,
        "use_case": "Legacy applications"
    }
}

# Display comparison
print("📊 OpenAI Embedding Models Comparison:\n")
for model_name, details in models_comparison.items():
    print(f"Model: {model_name}")
    print(f"  📏 Dimensions: {details['dimensions']}")
    print(f"  💰 Cost: ${details['cost_per_1m_tokens']}/1M tokens")
    print(f"  📝 Description: {details['description']}")
    print(f"  🎯 Use case: {details['use_case']}\n")
# Out:
# 📊 OpenAI Embedding Models Comparison:
#
# Model: text-embedding-3-small
#   📏 Dimensions: 1536
#   💰 Cost: $0.02/1M tokens
#   📝 Description: Good balance of performance and cost
#   🎯 Use case: General purpose, cost-effective
#
# Model: text-embedding-3-large
#   📏 Dimensions: 3072
#   💰 Cost: $0.13/1M tokens
#   📝 Description: Highest quality embeddings
#   🎯 Use case: When accuracy is critical
#
# Model: text-embedding-ada-002
#   📏 Dimensions: 1536
#   💰 Cost: $0.1/1M tokens
#   📝 Description: Previous generation model
#   🎯 Use case: Legacy applications

# %% [markdown]
# ## Gemini

# %%
gemini_embedding=GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-2-preview",google_api_key=google_api_key)
gemini_e=gemini_embedding.embed_query("What is Langchain?")
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\langchain_google_genai\embeddings.py:264, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     258     request: EmbedContentRequest = self._prepare_request(
#     259         text=text,
#     260         task_type=task_type,
#     261         title=title,
#     262         output_dimensionality=output_dimensionality,
#     263     )
# --> 264     result: EmbedContentResponse = self.client.embed_content(request)
#     265 except Exception as e:
#
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1305, in GenerativeServiceClient.embed_content(self, request, model, content, retry, timeout, metadata)
#    1304 # Send the request.
# ...

# %%
gemini_e
# Out:
# [-0.002225940814241767,
#  0.009764343500137329,
#  0.00908389687538147,
#  0.000792543520219624,
#  0.015371869318187237,
#  -0.012152268551290035,
#  -0.008822948671877384,
#  0.017184391617774963,
#  0.020157374441623688,
#  -0.050129104405641556,
#  -0.016079576686024666,
#  -0.009660272859036922,
#  -0.014463023282587528,
#  -0.003081707516685128,
#  0.01753873936831951,
#  0.003269192297011614,
#  0.0531364344060421,
#  -0.03295722231268883,
#  -0.0122603178024292,
#  -0.009174915961921215,
#  -0.02918866090476513,
#  0.009861908853054047,
#  -0.001973644131794572,
#  0.01888522505760193,
#  0.002928599715232849,
#  0.012274565175175667,
#  -0.022365178912878036,
#  -0.005394762847572565,
#  -0.017647717148065567,
#  0.12535704672336578,
#  -0.02322300523519516,
#  -0.006113218609243631,
#  -0.011590203270316124,
#  -0.0019576335325837135,
#  -0.014180152676999569,
#  0.007315285038203001,
#  -0.005847900174558163,
#  0.00240523018874228,
#  -0.004184736404567957,
# ...

# %% [markdown]
# Multiple texts

# %%
multiple_text=["What is Langchain"]
multiple_text_embedding_openai=embedding_openai.embed_documents(multiple_text)
print(multiple_text_embedding_openai)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 multiple_text=["What is Langchain"]
# ----> 2 multiple_text_embedding_openai=embedding_openai.embed_documents(multiple_text)
#       3 print(multiple_text_embedding_openai)
#
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\langchain_openai\embeddings\base.py:588, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     585 # NOTE: to keep things simple, we assume the list may contain texts longer
#     586 #       than the maximum context and use length-safe embedding function.
#     587 engine = cast(str, self.deployment)
# --> 588 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File c:\Users\ArnavBhatia\anaconda3\envs\llms\Lib\site-packages\langchain_openai\embeddings\base.py:483, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
# ...

# %% [markdown]
# ## Ollama

# %%
ol_embedding=OllamaEmbeddings(model="llama3.2:latest")
ol_embedding.embed_query("What is Langchain?")
# Out:
# [-0.018114492,
#  -0.005879089,
#  0.0023008154,
#  -0.0044996003,
#  -0.008619355,
#  0.00084393483,
#  0.025008574,
#  0.008939405,
#  -0.0017729267,
#  -0.0041414173,
#  0.014121224,
#  0.017228445,
#  0.021070778,
#  0.01630385,
#  -0.016416734,
#  0.007168195,
#  -0.029166102,
#  0.00581249,
#  0.010361306,
#  -0.009813855,
#  -0.005418945,
#  0.0024196703,
#  0.015550805,
#  0.0024075788,
#  0.0037208532,
#  -0.013903356,
#  -0.007757682,
#  -0.019041203,
#  0.01016073,
#  -0.019987402,
#  -0.015993867,
#  -0.003753389,
#  0.022327859,
#  0.009182568,
#  -0.007878711,
#  0.011272774,
#  -0.008343792,
#  0.004742121,
#  -0.006652604,
#  0.004847953,
#  0.018050354,
#  0.018127996,
#  0.013110567,
#  0.013957826,
#  -0.00655652,
#  -0.0070258756,
#  0.019625673,
#  0.017972765,
#  -0.009589961,
#  -0.014417111,
#  0.012341889,
#  -0.007862176,
#  0.0024112104,
#  0.01960668,
#  0.008156623,
#  -0.030900171,
#  -0.0012906067,
#  -0.013721297,
#  0.0057398486,
#  0.0006361816,
# ...

# %%
multi_text=["What is Langchain?","What is RAG?","What is LLM?","What is Ollama?","What is Gemini?"]
multi_em=ol_embedding.embed_documents(multi_text)

# %%
print(len(multi_em))
for i in multi_em:
    print(i)
    print(len(i))
# Out:
# 5
# ...
