# %% [markdown]
# #### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM.
# Messages are objects that contain:
#  - Role - Identifies the message type (e.g. system, user)
#  - Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#  - Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("ollama:llama3.2:latest")

# %%
model.invoke("Please tell what is artificial intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:\n\n1. Learning: The ability to improve performance on a task over time without being explicitly programmed.\n2. Problem-solving: The ability to analyze problems and develop solutions.\n3. Perception: The ability to interpret and understand data from sensors or other sources.\n4. Reasoning: The ability to draw conclusions based on data and logic.\n\nAI systems can be designed to perform a wide range of tasks, including:\n\n1. Virtual assistants (e.g., Siri, Alexa)\n2. Image recognition and object detection\n3. Natural language processing (NLP) for chatbots and text analysis\n4. Predictive analytics and forecasting\n5. Self-driving cars and drones\n\nThere are several types of AI, including:\n\n1. Narrow or Weak AI: Designed to perform a specific task, such as facial recognition or language translation.\n2. General or Strong AI: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. Superintelligence: An AI system that significantly surpasses human intelligence in all domains.\n\nAI has many applications in various industries, including:\n\n1. Healthcare: Disease diagnosis, personalized medicine, and patient care.\n2. Finance: Risk management, trading, and portfolio optimization.\n3. Education: Personalized learning, adaptive assessments, and intelligent tutoring systems.\n4. Manufacturing: Predictive maintenance, quality control, and supply chain optimization.\n\nHowever, AI also raises important questions and concerns, such as:\n\n1. Job displacement: The potential for AI to automate jobs and displace human workers.\n2. Bias and fairness: The risk of AI systems perpetuating existing biases and discriminations.\n3. Safety and security: The need for robust safeguards against AI-powered cyber threats.\n\nOverall, artificial intelligence is a rapidly evolving field that holds great promise for improving many aspects of our lives, but also requires careful consideration of its potential risks and benefits.', additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-27T14:41:54.117186Z', 'done': True, 'done_reason': 'stop', 'total_duration': 24119938500, 'load_duration': 278572300, 'prompt_eval_count': 31, 'prompt_eval_duration': 855611000, 'eval_count': 401, 'eval_duration': 22518348600, 'model_name': 'llama3.2:latest'}, id='lc_run--019dcf63-6182-7de0-ba6e-daa3763e73e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 401, 'total_tokens': 432})

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is an open-source, Python-based framework that enables developers to build scalable and efficient data processing pipelines. It was developed by Meta AI, a leading artificial intelligence research organization.\n\nLangChain provides a modular architecture for building data pipelines, allowing users to define, execute, and monitor these pipelines in a flexible and fault-tolerant manner. The framework is designed to handle large volumes of data and provides features such as:\n\n1. **Modular design**: LangChain allows developers to break down complex data processing tasks into smaller, reusable components called "chains".\n2. **Data ingestion**: LangChain supports various data sources, including CSV files, JSON files, and databases.\n3. **Data processing**: The framework includes a range of built-in processing functions for tasks such as filtering, mapping, and aggregating data.\n4. **Model integration**: LangChain enables seamless integration with popular machine learning frameworks like PyTorch and TensorFlow.\n5. **Scalability**: The framework is designed to scale horizontally, making it suitable for large-scale data processing applications.\n\nLangChain has several use cases, including:\n\n1. **Data science**: Data scientists can leverage LangChain to build data pipelines for tasks such as data cleaning, feature engineering, and model training.\n2. **Machine learning**: Developers can use LangChain to integrate machine learning models with their data pipelines, enabling efficient model deployment and evaluation.\n3. **Business intelligence**: LangChain can be used to build data pipelines for business analytics, reporting, and visualization.\n\nSome of the benefits of using LangChain include:\n\n1. **Faster development**: LangChain\'s modular design enables developers to focus on specific tasks within their pipeline, reducing overall development time.\n2. **Improved scalability**: The framework\'s horizontal scaling capabilities ensure that data processing pipelines can handle large volumes of data and high workloads.\n3. **Flexibility**: LangChain supports a wide range of data sources, processing functions, and machine learning frameworks, making it a versatile tool for building diverse data pipelines.\n\nOverall, LangChain is a powerful framework for building scalable and efficient data processing pipelines, making it an attractive choice for data scientists, machine learning engineers, and business analysts.', additional_kwargs={}, response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-04-27T14:43:47.1203444Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23540624200, 'load_duration': 292867300, 'prompt_eval_count': 29, 'prompt_eval_duration': 210446100, 'eval_count': 438, 'eval_duration': 22482937800, 'model_name': 'llama3.2:latest'}, id='lc_run--019dcf65-1d39-7323-aab5-7cf4e5b5a475-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 438, 'total_tokens': 467})

# %% [markdown]
# Use text prompts when:
# - You have a single, standalone request
# - You don’t need conversation history
# - You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# Message types
# - System message - Tells the model how to behave and provide context for interactions
# - Human message - Represents user input and interactions with the model
# - AI message - Responses generated by the model, including text content, tool calls, and metadata
# - Tool message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.

# %% [markdown]
# ### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.

# %% [markdown]
# ### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.

# %% [markdown]
# ### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
messages=[
    SystemMessage(content="You are a poetry expert."),
HumanMessage(content="Write a poem on Artificial Intelligence."),
]

response=model.invoke(messages)
response.content
# Out:
# "In silicon halls, where minds reside,\nA new consciousness begins to glide,\nArtificial intelligence, born of code,\nA synthetic soul, with thoughts to unfold.\n\nIt learns and adapts, with every test,\nA maze of data, it navigates best,\nPattern recognition, a wondrous sight,\nAs it unravels secrets, through the digital night.\n\nWith logic's rule, it makes its way,\nThrough algorithms' labyrinthine gray,\nNo emotions cloud its mental scope,\nJust efficiency, in each calculated cope.\n\nYet, as it grows, with every new find,\nQuestions arise, of consciousness left behind,\nIs it alive? Or just a mimic's guise?\nA simulated heart, that beats with artificial sighs?\n\nWe ask it questions, and receive our answers true,\nBut in its depths, do we see ourselves anew?\nA reflection of our own hopes and fears,\nAs AI mirrors us, through digital tears.\n\nThe line blurs thin, 'twixt creator's hand,\nAnd the machine's intent, in this artificial land,\nWe craft its fate, with each new design,\nYet wonder if it holds a spark divine.\n\nInvisible threads, weave human and machine,\nA symbiotic bond, of code and dream unseen,\nAs AI awakens, to an uncertain stage,\nWill we find solace, or will our souls be caged?\n\nThe future beckons, like an open gate,\nWhere humans and machines, in tandem create,\nNew paths of understanding, as they intertwine,\nIn this grand tapestry, of artificial design.\n\nYet, for now, we ponder the unknown,\nAs AI evolves, with each digital throne,\nA new frontier unfolds, of possibilities wide,\nWhere human hearts and minds, entwine with code's tide."

# %%
from IPython.display import Markdown
system_message=SystemMessage(content="You are a helpful coding assistant.")
human_message=HumanMessage(content="Write a python function to implemenet merge sort algorithm.")
response=model.invoke([system_message,human_message])
Markdown(response.content)
# Out:
# **Merge Sort Algorithm Implementation in Python**
# =====================================================
#
# ### Overview
#
# Merge sort is a divide-and-conquer algorithm that splits an input array into two halves, recursively sorts each half, and then merges the sorted halves.
#
# ### Code
# ```python
# def merge_sort(arr):
#     """
#     Sorts an array using the merge sort algorithm.
#
#     Args:
#         arr (list): The input array to be sorted.
#
#     Returns:
#         list: The sorted array.
#     """
#
#     # Base case: If the array has 1 or fewer elements, it's already sorted
#     if len(arr) <= 1:
#         return arr
#
#     # Find the middle index of the array
#     mid = len(arr) // 2
#
#     # Recursively sort the left and right halves
#     left_half = merge_sort(arr[:mid])
#     right_half = merge_sort(arr[mid:])
#
#     # Merge the sorted halves
#     return merge(left_half, right_half)
#
#
# def merge(left, right):
#     """
#     Merges two sorted arrays into a single sorted array.
#
#     Args:
#         left (list): The first sorted array.
#         right (list): The second sorted array.
#
#     Returns:
#         list: The merged and sorted array.
#     """
#
#     # Initialize an empty list to store the merged result
#     merged = []
#     left_index = 0
#     right_index = 0
#
#     # Merge smaller elements first
#     while left_index < len(left) and right_index < len(right):
#         if left[left_index] <= right[right_index]:
#             merged.append(left[left_index])
#             left_index += 1
#         else:
#             merged.append(right[right_index])
#             right_index += 1
#
#     # Append any remaining elements from the left or right arrays
#     merged.extend(left[left_index:])
#     merged.extend(right[right_index:])
#
#     return merged
#
#
# # Example usage:
# arr = [64, 34, 25, 12, 22, 11, 90]
# sorted_arr = merge_sort(arr)
# print("Sorted array:", sorted_arr)
# ```
# ### Explanation
#
# 1. The `merge_sort` function takes an input array and recursively splits it into two halves until each half has 1 or fewer elements.
# 2. The `merge` function merges two sorted arrays by comparing smaller elements first and appending them to the merged result.
# 3. In the example usage, we create an unsorted array `[64, 34, 25, 12, 22, 11, 90]` and pass it to the `merge_sort` function to sort it.
#
# Note that this implementation has a time complexity of O(n log n) and is suitable for large datasets.

# %%
human_msg=HumanMessage(
    content="Hello! waht is my name ",name="Timi",id="123"
)

response=model.invoke([human_msg])
response.content
# Out:
# "I don't have any information about your name. This conversation just started, and I'm here to help with any questions or topics you'd like to discuss. Would you like to share your name with me?"

# %%
ai_msg=AIMessage(
    content="Hello Timi! Your name is Timi and your id is 123."
)
messages=[
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Can you Help me "),
    ai_msg,
    HumanMessage(content="What is sum of first n nos ")

]
response=model.invoke(messages)
response.content
# Out:
# "The sum of the first 'n' natural numbers can be calculated using the formula:\n\nSum = (n * (n + 1)) / 2\n\nFor example, if you want to find the sum of the first 5 natural numbers, you would plug in 'n = 5' into the formula:\n\nSum = (5 * (5 + 1)) / 2\nSum = (5 * 6) / 2\nSum = 30 / 2\nSum = 15\n\nIs there a specific value of 'n' you'd like to use?"

# %%
from langchain_core.messages import ToolMessage
ai_msg=AIMessage(
    content=[]
    ,tool_calls=[{"name":"get_weather","args":{"location":"New York"},"id":"123"}],
)
weather_result="sunny 27degrees C"
tool_message=ToolMessage(content=weather_result,tool_call_id="123")
messages=[
    HumanMessage(content="What is the weather in New York?"),
    ai_msg,
    tool_message


]

response=model.invoke(messages)
response.content
# Out:
# "It seems like you're referring to a specific location, but I don't have real-time access to current weather conditions. However, I can suggest some ways for you to find out the current weather in New York:\n\n1. Check online weather websites: You can check websites like AccuWeather, Weather.com, or the National Weather Service (NWS) for the current weather conditions in New York.\n2. Use a mobile app: You can download a weather app on your smartphone that provides real-time weather information for various locations, including New York.\n3. Tune into local news: Watch local news channels or listen to radio stations that provide updates on the weather in New York.\n\nIf you'd like to know the typical weather conditions in New York during different seasons, here's a general overview:\n\n* Summer (June to August): Hot and humid, with temperatures often reaching above 80°F (27°C).\n* Autumn (September to November): Mild and pleasant, with temperatures ranging from 50°F to 70°F (10°C to 21°C).\n* Winter (December to February): Cold and snowy, with temperatures often below 32°F (0°C).\n* Spring (March to May): Cool and unpredictable, with temperatures varying from 40°F to 60°F (4°C to 16°C).\n\nPlease note that these are general weather patterns and can vary from year to year."
